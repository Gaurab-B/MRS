# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
path = "movies.csv"                                     #MOVIES.CSV
moviescsv=pd.read_csv(path, usecols=['movieId','title','genres'], dtype={'movieId':'int32','title':'str'})
moviescsv.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
moviescsv.drop_duplicates(subset="title", keep='last',inplace=True)  #The 'inplace=True' ensures that the original 'movies' DataFrame is modified.
moviescsv
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62325 rows x 3 columns]

# %%
import re #regularexpressions
import string
def clean_text_func(text):
    '''Make text lowercase, removing special characters'''
    text = text.lower()
    # remove multiple whitespaces
    text = re.sub('\s+',' ', text)
    # remove characters that not words
    text=re.sub('[^a-zA-Z0-9]',' ',text)
    return text

clean_text = lambda x: clean_text_func(x)    #This lambda function allows us to apply the cleaning function conveniently in a single line.

# %%
moviescsv.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
if 'all_data' not in moviescsv:                #this lines prevent from re-runing the data which causes multiple datasets.
    moviescsv['all_data'] = moviescsv[moviescsv.columns[3:]].apply(
        lambda x: ' '.join(x.astype(str)),
        axis=1
        )

# %%
import nltk
from nltk import WordNetLemmatizer
from nltk.corpus import stopwords
import re
nltk.download('wordnet')

def lemma_tokens(tokens, lemma):
    lemma_result = [lemma.lemmatize(item) for item in tokens]
    return(lemma_result)

def tokenize(text):
    lemma = nltk.WordNetLemmatizer()
    text = re.sub("[^a-zA-Z]", " ", text)
    tokens = nltk.word_tokenize(text)

    # English Stop words
    # Re-add the additional stop words since we are recreating the document-term matrix
    stop_words = stopwords.words('english')

    # Remove all stop words: no_stops
    no_stops = [t for t in tokens if t not in stop_words]

    lemma = lemma_tokens(no_stops, lemma)
    return(lemma)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gauur\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
path2 = "ratings.csv"                                 #RATINGS.CSV
ratings = pd.read_csv(path2,
                      usecols=['userId', 'movieId', 'rating', 'timestamp'],
                      dtype={'userId': 'Int32', 'movieId': 'Int32', 'rating': 'float32'},
                      na_values={'userId': -1, 'movieId': -1, 'rating': 0.0})

ratings.head()
# Out:
#    userId  movieId  rating     timestamp
# 0       1      296     5.0  1.147880e+09
# 1       1      306     3.5  1.147869e+09
# 2       1      307     5.0  1.147869e+09
# 3       1      665     5.0  1.147879e+09
# 4       1      899     3.5  1.147869e+09

# %%
ratings.dtypes
# Out:
# userId         Int32
# movieId        Int32
# rating       float32
# timestamp    float64
# dtype: object

# %%
tags = pd.read_csv("tags.csv")
tags.head(2)
# Out:
#    userId  movieId      tag     timestamp
# 0       3      260  classic  1.439472e+09
# 1       3      260   sci-fi  1.439472e+09

# %%
ratings_t = ratings.groupby('userId').filter(lambda x: len(x) > 80)
ratings_t #limit ratings to user ratings that have rated more than 80 movies
# Out:
#          userId  movieId  rating     timestamp
# 70            2        1     3.5  1.141416e+09
# 71            2       62     0.5  1.141417e+09
# 72            2      110     5.0  1.141417e+09
# 73            2      150     4.0  1.141416e+09
# 74            2      151     4.5  1.141416e+09
# ...         ...      ...     ...           ...
# 3077630   20261    79132     5.0  1.449025e+09
# 3077631   20261    80463     5.0  1.449026e+09
# 3077632   20261    80489     5.0  1.449027e+09
# 3077633   20261    81562     5.0  1.449026e+09
# 3077634   20261     <NA>     NaN           NaN
#
# [2615732 rows x 4 columns]

# %%
ratings_t.shape
# Out:
# (2615732, 4)

# %%
movie_list_rating = ratings_t.movieId.unique().tolist() #list the movie titles that survive the filtering
movie_list_rating
# Out:
# [1,
#  62,
#  110,
#  150,
#  151,
#  236,
#  260,
#  261,
#  266,
#  318,
#  333,
#  349,
#  356,
#  364,
#  380,
#  457,
#  480,
#  497,
#  524,
#  527,
#  534,
#  553,
#  588,
#  589,
#  653,
#  733,
#  858,
#  914,
#  953,
#  1035,
#  1080,
#  1136,
#  1196,
#  1197,
#  1198,
#  1201,
#  1210,
#  1246,
#  1257,
#  1270,
#  1271,
#  1275,
#  1283,
#  1287,
#  1291,
#  1293,
#  1299,
#  1302,
#  1356,
#  1374,
#  1376,
#  1393,
#  1431,
#  1465,
#  1485,
#  1488,
#  1527,
#  1580,
#  1584,
#  1587,
#  1610,
#  1653,
#  1672,
#  1674,
#  1682,
#  1693,
#  1722,
#  1873,
#  1907,
#  1923,
#  1957,
#  1968,
#  2028,
#  2081,
#  2083,
#  2115,
#  2138,
#  2139,
#  2150,
#  2194,
#  2268,
#  2273,
#  2294,
#  2324,
#  2355,
#  2359,
#  2406,
#  2470,
#  2496,
#  2501,
#  2571,
#  2617,
#  2640,
#  2643,
#  2694,
#  2720,
#  2745,
#  2761,
#  2762,
#  2797,
#  2918,
#  2987,
#  3098,
#  3105,
#  3107,
#  3114,
#  3148,
#  3175,
#  3360,
#  3396,
#  3479,
#  3510,
#  3578,
#  3793,
#  3889,
#  3916,
#  3948,
#  3994,
#  4016,
#  4019,
#  4022,
#  4023,
#  4103,
#  4299,
#  4306,
#  4535,
#  4571,
#  4720,
#  4857,
#  4874,
#  4886,
#  4896,
#  4963,
#  4993,
#  4995,
#  5010,
#  5103,
#  5349,
#  5418,
#  5445,
#  5574,
#  5816,
#  5952,
#  5955,
#  6156,
#  6157,
#  6213,
#  6287,
#  6311,
#  6333,
#  6539,
#  6565,
#  6753,
#  6879,
#  6947,
#  7004,
#  7007,
#  7075,
#  7090,
#  7143,
#  7153,
#  7162,
#  7386,
#  7624,
#  8010,
#  8360,
#  8368,
#  8636,
#  8665,
#  8958,
#  8961,
#  8970,
#  27821,
#  30749,
#  30848,
#  31923,
#  33166,
#  33493,
#  33660,
#  33794,
#  34162,
#  35836,
#  36527,
#  40815,
#  29,
#  32,
#  50,
#  111,
#  172,
#  173,
#  214,
#  293,
#  296,
#  442,
#  541,
#  593,
#  741,
#  745,
#  778,
#  780,
#  912,
#  913,
#  924,
#  1089,
#  1127,
#  1148,
#  1200,
#  1206,
#  1208,
#  1213,
#  1214,
#  1217,
#  1221,
#  1222,
#  1240,
#  1252,
#  1274,
#  1320,
#  1676,
#  1732,
#  1748,
#  1882,
#  1909,
#  48394,
#  48516,
#  48738,
#  48774,
#  48780,
#  49272,
#  49274,
#  49278,
#  49530,
#  49822,
#  50068,
#  50872,
#  51255,
#  51662,
#  51935,
#  52604,
#  52722,
#  52950,
#  53121,
#  53125,
#  53129,
#  53464,
#  53972,
#  53996,
#  54001,
#  54286,
#  54503,
#  54648,
#  54997,
#  55232,
#  55765,
#  55805,
#  55820,
#  56145,
#  56156,
#  56171,
#  56174,
#  56587,
#  56782,
#  56949,
#  57368,
#  57528,
#  57640,
#  57669,
#  58025,
#  58559,
#  59315,
#  59369,
#  59501,
#  59615,
#  59784,
#  59900,
#  60040,
#  60069,
#  60072,
#  60074,
#  60126,
#  60684,
#  60756,
#  60760,
#  61132,
#  61160,
#  61248,
#  61323,
#  61350,
#  62849,
#  62999,
#  63062,
#  63072,
#  63113,
#  63859,
#  63876,
#  64030,
#  64614,
#  64839,
#  64957,
#  65514,
#  65682,
#  66097,
#  67255,
#  67923,
#  68157,
#  68319,
#  68358,
#  68554,
#  68791,
#  68793,
#  68952,
#  69122,
#  69481,
#  69526,
#  69640,
#  69844,
#  70286,
#  70293,
#  70305,
#  70336,
#  71057,
#  71156,
#  71464,
#  71530,
#  71535,
#  72011,
#  72209,
#  72378,
#  72641,
#  72701,
#  72998,
#  73017,
#  73268,
#  73321,
#  73323,
#  74458,
#  74789,
#  76077,
#  76093,
#  76251,
#  77561,
#  78469,
#  78499,
#  79091,
#  79132,
#  79224,
#  79293,
#  79695,
#  80363,
#  80463,
#  81229,
#  81537,
#  81564,
#  81591,
#  81834,
#  81845,
#  82095,
#  82202,
#  82461,
#  83349,
#  83613,
#  84152,
#  84772,
#  84954,
#  85020,
#  85056,
#  85131,
#  85261,
#  85414,
#  86332,
#  86644,
#  86880,
#  86911,
#  87232,
#  87306,
#  87430,
#  87520,
#  87876,
#  88125,
#  88140,
#  88405,
#  88744,
#  89492,
#  89745,
#  89753,
#  90249,
#  90866,
#  91500,
#  91529,
#  91542,
#  91630,
#  91658,
#  91974,
#  91976,
#  93363,
#  93805,
#  94018,
#  94677,
#  94777,
#  94864,
#  95441,
#  95510,
#  95875,
#  96079,
#  96610,
#  96691,
#  96737,
#  96861,
#  97225,
#  97306,
#  97921,
#  97923,
#  98809,
#  99112,
#  99114,
#  101864,
#  102125,
#  102407,
#  102445,
#  102686,
#  102716,
#  102880,
#  102903,
#  103075,
#  103141,
#  103228,
#  103249,
#  103253,
#  103384,
#  103772,
#  103810,
#  104241,
#  104243,
#  104841,
#  105213,
#  106002,
#  106072,
#  106100,
#  106487,
#  106489,
#  106782,
#  106920,
#  107348,
#  107406,
#  108190,
#  108932,
#  108945,
#  109374,
#  109487,
#  109578,
#  110102,
#  110407,
#  110730,
#  111113,
#  111360,
#  111362,
#  111443,
#  111659,
#  111759,
#  112138,
#  112171,
#  112370,
#  112552,
#  112556,
#  112623,
#  112852,
#  113345,
#  114180,
#  114847,
#  114935,
#  115569,
#  115617,
#  115713,
#  116797,
#  116823,
#  116897,
#  117529,
#  117533,
#  120466,
#  122882,
#  122886,
#  122892,
#  122896,
#  122900,
#  122906,
#  122912,
#  122914,
#  122918,
#  122920,
#  122922,
#  122924,
#  129354,
#  130490,
#  130634,
#  132046,
#  134130,
#  134853,
#  135133,
#  135143,
#  135536,
#  135569,
#  136020,
#  136449,
#  136469,
#  136864,
#  139385,
#  139644,
#  140956,
#  142509,
#  143385,
#  148626,
#  148855,
#  149406,
#  151763,
#  158238,
#  158966,
#  159093,
#  164179,
#  166528,
#  166635,
#  168252,
#  168612,
#  171763,
#  175197,
#  176101,
#  176371,
#  179819,
#  182823,
#  187541,
#  187593,
#  1036,
#  1220,
#  1265,
#  1278,
#  1288,
#  2716,
#  2791,
#  2951,
#  2985,
#  2993,
#  3033,
#  3039,
#  3624,
#  3671,
#  3681,
#  4709,
#  4974,
#  5110,
#  5299,
#  5444,
#  5618,
#  7324,
#  7451,
#  7569,
#  8914,
#  38038,
#  44193,
#  44665,
#  45431,
#  46948,
#  48982,
#  49396,
#  49649,
#  50601,
#  53956,
#  54881,
#  68954,
#  71264,
#  72226,
#  74530,
#  76175,
#  77866,
#  78893,
#  79185,
#  79702,
#  83134,
#  86345,
#  91485,
#  93510,
#  93838,
#  93840,
#  96110,
#  97304,
#  97913,
#  103341,
#  106916,
#  111781,
#  115122,
#  115149,
#  119145,
#  122904,
#  127098,
#  138036,
#  142115,
#  148426,
#  152081,
#  156706,
#  159817,
#  168248,
#  171011,
#  173145,
#  174055,
#  179401,
#  180989,
#  182715,
#  189333,
#  195159,
#  200818,
#  200838,
#  203375,
#  203519,
#  19,
#  36,
#  39,
#  47,
#  88,
#  95,
#  104,
#  113,
#  122,
#  141,
#  147,
#  153,
#  170,
#  191,
#  216,
#  218,
#  219,
#  224,
#  231,
#  235,
#  238,
#  248,
#  253,
#  267,
#  277,
#  288,
#  292,
#  300,
#  312,
#  337,
#  340,
#  342,
#  344,
#  350,
#  372,
#  416,
#  432,
#  435,
#  440,
#  441,
#  477,
#  487,
#  491,
#  500,
#  542,
#  590,
#  592,
#  595,
#  608,
#  628,
#  671,
#  736,
#  784,
#  786,
#  788,
#  802,
#  839,
#  1016,
#  1042,
#  1047,
#  1061,
#  1073,
#  1093,
#  1097,
#  1120,
#  1194,
#  1234,
#  1235,
#  1290,
#  1344,
#  1357,
#  1380,
#  1407,
#  1409,
#  3,
#  6,
#  7,
#  10,
#  11,
#  16,
#  18,
#  21,
#  25,
#  27,
#  69,
#  103,
#  112,
#  125,
#  145,
#  161,
#  163,
#  165,
#  180,
#  198,
#  201,
#  207,
#  209,
#  223,
#  225,
#  237,
#  290,
#  316,
#  325,
#  358,
#  377,
#  428,
#  454,
#  474,
#  490,
#  494,
#  511,
#  551,
#  575,
#  594,
#  648,
#  708,
#  725,
#  750,
#  785,
#  799,
#  805,
#  875,
#  903,
#  904,
#  923,
#  1012,
#  1020,
#  1022,
#  1029,
#  1032,
#  1049,
#  1092,
#  1101,
#  1129,
#  1203,
#  1207,
#  1242,
#  1258,
#  ...]

# %%
len(ratings_t.movieId.unique())/len(moviescsv.movieId.unique()) * 100 #we still have 97% of the original movie titles in ratings dataframe
# Out:
# 50.685920577617324

# %%
len(ratings_t.userId.unique())/len(ratings.userId.unique()) * 100 #we have only 44% of the users, So now lets filter the movies data frame
# Out:
# 45.145846700557726

# %%
movies = moviescsv[moviescsv.movieId.isin(movie_list_rating)]
movies.shape
# Out:
# (31520, 4)

# %%
mapping_file = dict(zip(movies.title.tolist(), movies.movieId.tolist()))
mapping_file
# Out:
# {'Toy Story (1995)': 1,
#  'Jumanji (1995)': 2,
#  'Grumpier Old Men (1995)': 3,
#  'Waiting to Exhale (1995)': 4,
#  'Father of the Bride Part II (1995)': 5,
#  'Heat (1995)': 6,
#  'Sabrina (1995)': 7,
#  'Tom and Huck (1995)': 8,
#  'Sudden Death (1995)': 9,
#  'GoldenEye (1995)': 10,
#  'American President, The (1995)': 11,
#  'Dracula: Dead and Loving It (1995)': 12,
#  'Balto (1995)': 13,
#  'Nixon (1995)': 14,
#  'Cutthroat Island (1995)': 15,
#  'Casino (1995)': 16,
#  'Sense and Sensibility (1995)': 17,
#  'Four Rooms (1995)': 18,
#  'Ace Ventura: When Nature Calls (1995)': 19,
#  'Money Train (1995)': 20,
#  'Get Shorty (1995)': 21,
#  'Copycat (1995)': 22,
#  'Assassins (1995)': 23,
#  'Powder (1995)': 24,
#  'Leaving Las Vegas (1995)': 25,
#  'Othello (1995)': 26,
#  'Now and Then (1995)': 27,
#  'Persuasion (1995)': 28,
#  'City of Lost Children, The (Cité des enfants perdus, La) (1995)': 29,
#  'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)': 30,
#  'Dangerous Minds (1995)': 31,
#  'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)': 32,
#  'Wings of Courage (1995)': 33,
#  'Babe (1995)': 34,
#  'Carrington (1995)': 35,
#  'Dead Man Walking (1995)': 36,
#  'Across the Sea of Time (1995)': 37,
#  'It Takes Two (1995)': 38,
#  'Clueless (1995)': 39,
#  'Cry, the Beloved Country (1995)': 40,
#  'Richard III (1995)': 41,
#  'Dead Presidents (1995)': 42,
#  'Restoration (1995)': 43,
#  'Mortal Kombat (1995)': 44,
#  'To Die For (1995)': 45,
#  'How to Make an American Quilt (1995)': 46,
#  'Seven (a.k.a. Se7en) (1995)': 47,
#  'Pocahontas (1995)': 48,
#  'When Night Is Falling (1995)': 49,
#  'Usual Suspects, The (1995)': 50,
#  'Guardian Angel (1994)': 51,
#  'Mighty Aphrodite (1995)': 52,
#  'Lamerica (1994)': 53,
#  'Big Green, The (1995)': 54,
#  'Georgia (1995)': 55,
#  'Kids of the Round Table (1995)': 56,
#  'Home for the Holidays (1995)': 57,
#  'Postman, The (Postino, Il) (1994)': 58,
#  'Confessional, The (Confessionnal, Le) (1995)': 59,
#  'Indian in the Cupboard, The (1995)': 60,
#  'Eye for an Eye (1996)': 61,
#  "Mr. Holland's Opus (1995)": 62,
#  "Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)": 63,
#  'Two if by Sea (1996)': 64,
#  'Bio-Dome (1996)': 65,
#  'Lawnmower Man 2: Beyond Cyberspace (1996)': 66,
#  'Two Bits (1995)': 67,
#  'French Twist (Gazon maudit) (1995)': 68,
#  'Friday (1995)': 69,
#  'From Dusk Till Dawn (1996)': 70,
#  'Fair Game (1995)': 71,
#  'Kicking and Screaming (1995)': 72,
#  'Misérables, Les (1995)': 73,
#  'Bed of Roses (1996)': 74,
#  'Big Bully (1996)': 75,
#  'Screamers (1995)': 76,
#  'Nico Icon (1995)': 77,
#  'Crossing Guard, The (1995)': 78,
#  'Juror, The (1996)': 79,
#  'White Balloon, The (Badkonake sefid) (1995)': 80,
#  "Things to Do in Denver When You're Dead (1995)": 81,
#  "Antonia's Line (Antonia) (1995)": 82,
#  'Once Upon a Time... When We Were Colored (1995)': 83,
#  'Last Summer in the Hamptons (1995)': 84,
#  'Angels and Insects (1995)': 85,
#  'White Squall (1996)': 86,
#  'Dunston Checks In (1996)': 87,
#  'Black Sheep (1996)': 88,
#  'Nick of Time (1995)': 89,
#  'The Journey of August King (1995)': 90,
#  'Mary Reilly (1996)': 92,
#  'Vampire in Brooklyn (1995)': 93,
#  'Beautiful Girls (1996)': 94,
#  'Broken Arrow (1996)': 95,
#  'In the Bleak Midwinter (1995)': 96,
#  'Hate (Haine, La) (1995)': 97,
#  'Shopping (1994)': 98,
#  'Heidi Fleiss: Hollywood Madam (1995)': 99,
#  'City Hall (1996)': 100,
#  'Bottle Rocket (1996)': 101,
#  'Mr. Wrong (1996)': 102,
#  'Unforgettable (1996)': 103,
#  'Happy Gilmore (1996)': 104,
#  'Bridges of Madison County, The (1995)': 105,
#  'Nobody Loves Me (Keiner liebt mich) (1994)': 106,
#  'Muppet Treasure Island (1996)': 107,
#  'Catwalk (1996)': 108,
#  'Headless Body in Topless Bar (1995)': 109,
#  'Braveheart (1995)': 110,
#  'Taxi Driver (1976)': 111,
#  'Rumble in the Bronx (Hont faan kui) (1995)': 112,
#  'Before and After (1996)': 113,
#  "Margaret's Museum (1995)": 114,
#  'Happiness Is in the Field (Bonheur est dans le pré, Le) (1995)': 115,
#  'Anne Frank Remembered (1995)': 116,
#  "Young Poisoner's Handbook, The (1995)": 117,
#  'If Lucy Fell (1996)': 118,
#  'Steal Big, Steal Little (1995)': 119,
#  'Race the Sun (1996)': 120,
#  'Boys of St. Vincent, The (1992)': 121,
#  'Boomerang (1992)': 122,
#  'Chungking Express (Chung Hing sam lam) (1994)': 123,
#  "Star Maker, The (Uomo delle stelle, L') (1995)": 124,
#  'Flirting With Disaster (1996)': 125,
#  'NeverEnding Story III, The (1994)': 126,
#  'Silences of the Palace, The (Saimt el Qusur) (1994)': 127,
#  "Jupiter's Wife (1994)": 128,
#  'Pie in the Sky (1996)': 129,
#  'Angela (1995)': 130,
#  'Frankie Starlight (1995)': 131,
#  'Jade (1995)': 132,
#  'Nueba Yol (1995)': 133,
#  'Sonic Outlaws (1995)': 134,
wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die) (1993)': 363,
#  'Lion King, The (1994)': 364,
#  'Little Buddha (1993)': 365,
#  "Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994)": 366,
#  'Mask, The (1994)': 367,
#  'Maverick (1994)': 368,
#  'Mrs. Parker and the Vicious Circle (1994)': 369,
#  'Naked Gun 33 1/3: The Final Insult (1994)': 370,
#  'Paper, The (1994)': 371,
#  'Reality Bites (1994)': 372,
#  'Red Rock West (1992)': 373,
#  'Richie Rich (1994)': 374,
#  'Safe Passage (1994)': 375,
#  'River Wild, The (1994)': 376,
#  'Speed (1994)': 377,
#  'Speechless (1994)': 378,
#  'Timecop (1994)': 379,
#  'True Lies (1994)': 380,
#  'When a Man Loves a Woman (1994)': 381,
#  'Wolf (1994)': 382,
#  'Wyatt Earp (1994)': 383,
#  'Bad Company (1995)': 384,
#  'Man of No Importance, A (1994)': 385,
#  'S.F.W. (1994)': 386,
#  'Low Down Dirty Shame, A (1994)': 387,
#  'Boys Life (1995)': 388,
#  'Colonel Chabert, Le (1994)': 389,
#  'Faster Pussycat! Kill! Kill! (1965)': 390,
#  "Jason's Lyric (1994)": 391,
#  'Secret Adventures of Tom Thumb, The (1993)': 392,
#  'Street Fighter (1994)': 393,
#  'Coldblooded (1995)': 394,
#  'Desert Winds (1995)': 395,
#  'Fall Time (1995)': 396,
#  'Fear, The (1995)': 397,
#  'Frank and Ollie (1995)': 398,
#  'Girl in the Cadillac (1995)': 399,
#  'Homage (1995)': 400,
#  'Mirage (1995)': 401,
#  'Open Season (1996)': 402,
#  'Two Crimes (Dos crímenes) (1995)': 403,
#  'Brother Minister: The Assassination of Malcolm X (1994)': 404,
#  'Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994)': 405,
#  'Federal Hill (1994)': 406,
#  'In the Mouth of Madness (1995)': 407,
#  '8 Seconds (1994)': 408,
#  'Above the Rim (1994)': 409,
#  'Addams Family Values (1993)': 410,
#  'Martin Lawrence: You So Crazy (1994)': 411,
#  'Age of Innocence, The (1993)': 412,
#  'Airheads (1994)': 413,
#  'Air Up There, The (1994)': 414,
#  'Another Stakeout (1993)': 415,
#  'Bad Girls (1994)': 416,
#  'Barcelona (1994)': 417,
#  'Being Human (1993)': 418,
#  'Beverly Hillbillies, The (1993)': 419,
#  'Beverly Hills Cop III (1994)': 420,
#  'Black Beauty (1994)': 421,
#  'Blink (1994)': 422,
#  'Blown Away (1994)': 423,
#  'Blue Chips (1994)': 424,
#  'Blue Sky (1994)': 425,
#  'Body Snatchers (1993)': 426,
#  'Boxing Helena (1993)': 427,
#  'Bronx Tale, A (1993)': 428,
#  'Cabin Boy (1994)': 429,
#  'Calendar Girl (1993)': 430,
#  "Carlito's Way (1993)": 431,
#  "City Slickers II: The Legend of Curly's Gold (1994)": 432,
#  'Clean Slate (1994)': 433,
#  'Cliffhanger (1993)': 434,
#  'Coneheads (1993)': 435,
#  'Dances with Wolves (1990)': 590,
#  'Tough and Deadly (1995)': 591,
#  'Batman (1989)': 592,
#  'Silence of the Lambs, The (1991)': 593,
#  'Snow White and the Seven Dwarfs (1937)': 594,
#  'Beauty and the Beast (1991)': 595,
#  'Pinocchio (1940)': 596,
#  'Pretty Woman (1990)': 597,
#  'Window to Paris (Okno v Parizh) (1994)': 598,
#  'Wild Bunch, The (1969)': 599,
#  'Love and a .45 (1994)': 600,
#  "Wooden Man's Bride, The (Yan shen) (1994)": 601,
#  'Great Day in Harlem, A (1994)': 602,
#  'Bye Bye, Love (1995)': 603,
#  'Criminals (1996)': 604,
#  'One Fine Day (1996)': 605,
#  'Candyman: Farewell to the Flesh (1995)': 606,
#  'Century (1993)': 607,
#  'Fargo (1996)': 608,
#  'Homeward Bound II: Lost in San Francisco (1996)': 609,
#  'Heavy Metal (1981)': 610,
#  'Hellraiser: Bloodline (1996)': 611,
#  'Pallbearer, The (1996)': 612,
#  'Jane Eyre (1996)': 613,
#  'Loaded (1994)': 614,
#  'Bread and Chocolate (Pane e cioccolata) (1973)': 615,
#  'Aristocats, The (1970)': 616,
#  'Flower of My Secret, The (La flor de mi secreto) (1995)': 617,
#  'Two Much (1995)': 618,
#  'Ed (1996)': 619,
#  'Scream of Stone (Cerro Torre: Schrei aus Stein) (1991)': 620,
#  'My Favorite Season (1993)': 621,
#  'Modern Affair, A (1995)': 623,
#  'Asfour Stah (1990)': 625,
#  'Thin Line Between Love and Hate, A (1996)': 626,
#  'Last Supper, The (1995)': 627,
#  'Primal Fear (1996)': 628,
#  'Rude (1995)': 629,
#  'Carried Away (1996)': 630,
#  'All Dogs Go to Heaven 2 (1996)': 631,
#  'Land and Freedom (Tierra y libertad) (1995)': 632,
#  'Denise Calls Up (1995)': 633,
#  'Theodore Rex (1995)': 634,
#  'Family Thing, A (1996)': 635,
#  'Frisk (1995)': 636,
#  'Sgt. Bilko (1996)': 637,
#  'Jack and Sarah (1995)': 638,
#  'Girl 6 (1996)': 639,
#  'Diabolique (1996)': 640,
#  'Little Indian, Big City (Un indien dans la ville) (1994)': 641,
#  'Roula (1995)': 642,
#  'Peanuts - Die Bank zahlt alles (1996)': 643,
#  'Happy Weekend (1996)': 644,
#  'Nelly & Monsieur Arnaud (1995)': 645,
#  'Courage Under Fire (1996)': 647,
#  'Mission: Impossible (1996)': 648,
#  'Cold Fever (Á köldum klaka) (1995)': 649,
#  'Moll Flanders (1996)': 650,
#  'Superweib, Das (1996)': 651,
#  '301, 302 (301/302) (1995)': 652,
#  'Dragonheart (1996)': 653,
#  'And Nobody Weeps for Me (Und keiner weint mir nach) (1996)': 654,
#  "My Mother's Courage (Mutters Courage) (1995)": 655,
#  'Eddie (1996)': 656,
#  'Yankee Zulu (1994)': 657,
#  "Billy's Holiday (1995)": 658,
#  'Purple Noon (Plein soleil) (1960)': 659,
#  'August (1996)': 660,
#  'James and the Giant Peach (1996)': 661,
#  'Fear (1996)': 662,
#  'Kids in the Hall: Brain Candy (1996)': 663,
#  'Faithful (1996)': 664,
#  'Underground (1995)': 665,
#  'All Things Fair (Lust och fägring stor) (1995)': 666,
#  'Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite) (1996)': 667,
#  'Song of the Little Road (Pather Panchali) (1955)': 668,
#  'World of Apu, The (Apur Sansar) (1959)': 670,
#  'Mystery Science Theater 3000: The Movie (1996)': 671,
#  'Tarantella (1995)': 672,
#  'Space Jam (1996)': 673,
#  'Barbarella (1968)': 674,
#  'Hostile Intentions (1994)': 675,
#  'They Bite (1996)': 676,
#  'Some Folks Call It a Sling Blade (1993)': 678,
#  'Run of the Country, The (1995)': 679,
#  'Alphaville (Alphaville, une étrange aventure de Lemmy Caution) (1965)': 680,
#  'Coup de torchon (Clean Slate) (1981)': 681,
#  'Tigrero: A Film That Was Never Made (1994)': 682,
#  "Eye of Vichy, The (Oeil de Vichy, L') (1993)": 683,
#  'Windows (1980)': 684,
#  "It's My Party (1996)": 685,
#  'Country Life (1994)': 687,
#  'Operation Dumbo Drop (1995)': 688,
#  'Promise, The (Versprechen, Das) (1995)': 690,
#  'Mrs. Winterbourne (1996)': 691,
#  'Solo (1996)': 692,
#  'Under the Domim Tree (Etz Hadomim Tafus) (1994)': 693,
#  'Substitute, The (1996)': 694,
#  'True Crime (1996)': 695,
#  'Butterfly Kiss (1995)': 696,
#  'Feeling Minnesota (1996)': 697,
#  'Delta of Venus (1995)': 698,
#  'To Cross the Rubicon (1991)': 699,
#  'Angus (1995)': 700,
#  'Daens (1992)': 701,
#  'Faces (1968)': 702,
#  'Boys (1996)': 703,
#  'Quest, The (1996)': 704,
#  'Cosi (1996)': 705,
#  'Sunset Park (1996)': 706,
#  'Mulholland Falls (1996)': 707,
#  'Truth About Cats & Dogs, The (1996)': 708,
#  'Oliver & Company (1988)': 709,
#  'Celtic Pride (1996)': 710,
#  'Flipper (1996)': 711,
#  'Captives (1994)': 712,
#  'Of Love and Shadows (1994)': 713,
#  'Dead Man (1995)': 714,
#  'Horseman on the Roof, The (Hussard sur le toit, Le) (1995)': 715,
#  'Switchblade Sisters (1975)': 716,
#  'Mouth to Mouth (Boca a boca) (1995)': 717,
#  'Visitors, The (Visiteurs, Les) (1993)': 718,
#  'Multiplicity (1996)': 719,
#  'Wallace & Gromit: The Best of Aardman Animation (1996)': 720,
#  'Halfmoon (Paul Bowles - Halbmond) (1995)': 721,
#  'Haunted World of Edward D. Wood Jr., The (1996)': 722,
#  'Two Friends (1986)': 723,
#  'Craft, The (1996)': 724,
#  'Great White Hype, The (1996)': 725,
#  'Last Dance (1996)': 726,
#  'War Stories (1995)': 727,
#  'Cold Comfort Farm (1995)': 728,
#  'Institute Benjamenta, or This Dream People Call Human Life (1995)': 729,
#  'Low Life (1994)': 730,
#  "Heaven's Prisoners (1996)": 731,
#  'Original Gangstas (1996)': 732,
#  'Rock, The (1996)': 733,
#  'Getting Away With Murder (1996)': 734,
#  'Cemetery Man (Dellamorte Dellamore) (1994)': 735,
#  'Twister (1996)': 736,
#  'Barb Wire (1996)': 737,
#  'Garçu, Le (1995)': 738,
#  'Honey Moon (Honigmond) (1996)': 739,
#  'Ghost in the Shell (Kôkaku kidôtai) (1995)': 741,
#  'Thinner (1996)': 742,
#  'Spy Hard (1996)': 743,
#  'Brothers in Trouble (1995)': 744,
#  'Wallace & Gromit: A Close Shave (1995)': 745,
#  'Force of Evil (1948)': 746,
#  'Stupids, The (1996)': 747,
#  'Arrival, The (1996)': 748,
#  'Man from Down Under, The (1943)': 749,
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)': 750,
#  'Careful (1992)': 751,
#  'Vermont Is For Lovers (1992)': 752,
#  'Month by the Lake, A (1995)': 753,
#  'Gold Diggers: The Secret of Bear Mountain (1995)': 754,
#  'Kim (1950)': 755,
#  'Carmen Miranda: Bananas Is My Business (1994)': 756,
#  'Ashes of Time (Dung che sai duk) (1994)': 757,
#  'Jar, The (Khomreh) (1992)': 758,
#  'Maya Lin: A Strong Clear Vision (1994)': 759,
#  'Stalingrad (1993)': 760,
#  'Phantom, The (1996)': 761,
#  'Striptease (1996)': 762,
#  'Last of the High Kings, The (a.k.a. Summer Fling) (1996)': 763,
#  'Heavy (1995)': 764,
#  'Jack (1996)': 765,
#  'I Shot Andy Warhol (1996)': 766,
#  'Grass Harp, The (1995)': 767,
#  "Someone Else's America (1995)": 768,
#  'Marlene Dietrich: Shadow and Light (1996)': 769,
#  'Costa Brava (1946)': 770,
#  'Life Is Rosy (a.k.a. Life Is Beautiful) (Vie est belle, La) (1987)': 771,
#  'Quartier Mozart (1992)': 772,
#  'Touki Bouki (1973)': 773,
#  "Wend Kuuni (a.k.a. God's Gift) (1982)": 774,
#  'Spirits of the Dead (1968)': 775,
#  'Babyfever (1994)': 776,
#  "Pharaoh's Army (1995)": 777,
#  'Trainspotting (1996)': 778,
#  "'Til There Was You (1997)": 779,
#  'Independence Day (a.k.a. ID4) (1996)': 780,
#  'Stealing Beauty (1996)': 781,
#  'Fan, The (1996)': 782,
#  'Hunchback of Notre Dame, The (1996)': 783,
#  'Cable Guy, The (1996)': 784,
#  'Kingpin (1996)': 785,
#  'Eraser (1996)': 786,
#  'Gate of Heavenly Peace, The (1995)': 787,
#  'Nutty Professor, The (1996)': 788,
#  'I, the Worst of All (Yo, la peor de todas) (1990)': 789,
#  'Unforgettable Summer, An (Un été inoubliable) (1994)': 790,
#  'Last Klezmer: Leopold Kozlowski, His Life and Music, The (1994)': 791,
#  'Hungarian Fairy Tale, A (Hol volt, hol nem volt) (1987)': 792,
#  "My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) (1993)": 793,
#  'Midnight Dancers (Sibak) (1994)': 794,
#  'Somebody to Love (1994)': 795,
#  'Very Natural Thing, A (1974)': 796,
#  'Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)': 797,
#  'Daylight (1996)': 798,
#  'Frighteners, The (1996)': 799,
#  'Lone Star (1996)': 800,
#  'Harriet the Spy (1996)': 801,
#  'Phenomenon (1996)': 802,
#  'Walking and Talking (1996)': 803,
#  "She's the One (1996)": 804,
#  'Time to Kill, A (1996)': 805,
#  'American Buffalo (1996)': 806,
#  'Rendezvous in Paris (Rendez-vous de Paris, Les) (1995)': 807,
#  'Alaska (1996)': 808,
#  'Fled (1996)': 809,
#  'Kazaam (1996)': 810,
#  'Magic Hunter (Büvös vadász) (1994)': 812,
#  'Larger Than Life (1996)': 813,
#  'Boy Called Hate, A (1995)': 814,
#  'Power 98 (1996)': 815,
#  'Two Deaths (1995)': 816,
#  'Very Brady Sequel, A (1996)': 818,
#  'Stefano Quantestorie (1993)': 819,
#  'Death in the Garden (Mort en ce jardin, La) (1956)': 820,
#  'Crude Oasis, The (1995)': 821,
#  'Hedd Wyn (1992)': 822,
#  'Collector, The (La collectionneuse) (1967)': 823,
#  'Kaspar Hauser (1993)': 824,
#  'Women Robbers (Diebinnen) (1995)': 826,
#  'Convent, The (O Convento) (1995)': 827,
#  'Adventures of Pinocchio, The (1996)': 828,
#  "Joe's Apartment (1996)": 829,
#  'First Wives Club, The (1996)': 830,
#  'Stonewall (1995)': 831,
#  'Ransom (1996)': 832,
#  'High School High (1996)': 833,
#  'Phat Beach (1996)': 834,
#  'Foxfire (1996)': 835,
#  'Chain Reaction (1996)': 836,
#  'Matilda (1996)': 837,
#  'Emma (1996)': 838,
#  'Crow: City of Angels, The (1996)': 839,
#  'House Arrest (1996)': 840,
#  'Eyes Without a Face (Yeux sans visage, Les) (1959)': 841,
#  'Tales from the Crypt Presents: Bordello of Blood (1996)': 842,
#  'Lotto Land (1995)': 843,
#  'Story of Xinghua, The (Xinghua san yue tian) (1994)': 844,
#  'Day the Sun Turned Cold, The (Tianguo niezi) (1994)': 845,
#  'Flirt (1995)': 846,
#  'Big Squeeze, The (1996)': 847,
#  'Spitfire Grill, The (1996)': 848,
#  'Escape from L.A. (1996)': 849,
#  'Cyclo (Xich lo) (1995)': 850,
#  'Basquiat (1996)': 851,
#  'Tin Cup (1996)': 852,
#  'Dingo (1991)': 853,
#  'Ballad of Narayama, The (Narayama Bushiko) (1958)': 854,
#  'Every Other Weekend (Un week-end sur deux) (1990)': 855,
#  'Mille bolle blu (1993)': 856,
#  'Crows and Sparrows (Wuya yu maque) (1949)': 857,
#  'Godfather, The (1972)': 858,
#  'Hippie Revolution, The (1996)': 859,
#  'Maybe, Maybe Not (Bewegte Mann, Der) (1994)': 860,
#  'Supercop (Police Story 3: Supercop) (Jing cha gu shi III: Chao ji jing cha) (1992)': 861,
#  'Manny & Lo (1996)': 862,
#  'Wife, The (1995)': 864,
#  'Small Faces (1996)': 865,
#  'Bound (1996)': 866,
#  'Carpool (1996)': 867,
#  'Death in Brunswick (1991)': 868,
#  'Kansas City (1996)': 869,
#  "Gone Fishin' (1997)": 870,
#  "Lover's Knot (1996)": 871,
#  "Vive L'Amour (Ai qing wan sui) (1994)": 872,
#  'Shadow of Angels (Schatten der Engel) (1976)': 873,
#  "It's a Wonderful Life (1946)": 953,
#  'Mr. Smith Goes to Washington (1939)': 954,
#  'Bringing Up Baby (1938)': 955,
#  'Penny Serenade (1941)': 956,
#  'Scarlet Letter, The (1926)': 957,
#  'Lady of Burlesque (1943)': 958,
#  'Of Human Bondage (1934)': 959,
#  'Angel on My Shoulder (1946)': 960,
#  'Little Lord Fauntleroy (1936)': 961,
#  'They Made Me a Criminal (1939)': 962,
#  'Inspector General, The (1949)': 963,
#  'Angel and the Badman (1947)': 964,
#  '39 Steps, The (1935)': 965,
#  'A Walk in the Sun (1945)': 966,
#  'Outlaw, The (1943)': 967,
#  'Night of the Living Dead (1968)': 968,
#  'African Queen, The (1951)': 969,
#  'Beat the Devil (1953)': 970,
#  'Cat on a Hot Tin Roof (1958)': 971,
#  'Last Time I Saw Paris, The (1954)': 972,
#  'Meet John Doe (1941)': 973,
#  'Algiers (1938)': 974,
#  'Something to Sing About (1937)': 975,
#  'Farewell to Arms, A (1932)': 976,
#  'Moonlight Murder (1936)': 977,
#  'Nothing Personal (1995)': 979,
#  'Yes, Madam (a.k.a. Police Assassins) (a.k.a. In the Line of Duty 2) (Huang gu shi jie) (1985)': 980,
#  'Dangerous Ground (1997)': 981,
#  'Picnic (1955)': 982,
#  'Madagascar Skin (1995)': 983,
#  'Pompatus of Love, The (1996)': 984,
#  'Small Wonders (1995)': 985,
#  'Fly Away Home (1996)': 986,
#  'Bliss (1997)': 987,
#  'Grace of My Heart (1996)': 988,
#  'Brother of Sleep (Schlafes Bruder) (1995)': 989,
#  'Maximum Risk (1996)': 990,
#  'Michael Collins (1996)': 991,
#  "Rich Man's Wife, The (1996)": 992,
#  'Infinity (1996)': 993,
#  'Big Night (1996)': 994,
#  'Last Man Standing (1996)': 996,
#  'Caught (1996)': 997,
#  'Set It Off (1996)': 998,
#  '2 Days in the Valley (1996)': 999,
#  'Curdled (1996)': 1000,
#  "Associate, The (Associé, L') (1979)": 1001,
#  "Ed's Next Move (1996)": 1002,
#  'Extreme Measures (1996)': 1003,
#  'Glimmer Man, The (1996)': 1004,
#  'D3: The Mighty Ducks (1996)': 1005,
#  'Chamber, The (1996)': 1006,
#  'Apple Dumpling Gang, The (1975)': 1007,
#  'Davy Crockett, King of the Wild Frontier (1955)': 1008,
#  'Escape to Witch Mountain (1975)': 1009,
#  'Love Bug, The (1969)': 1010,
#  'Herbie Rides Again (1974)': 1011,
#  'Old Yeller (1957)': 1012,
#  'Parent Trap, The (1961)': 1013,
#  'Pollyanna (1960)': 1014,
#  'Homeward Bound: The Incredible Journey (1993)': 1015,
#  'Shaggy Dog, The (1959)': 1016,
#  'Swiss Family Robinson (1960)': 1017,
#  'That Darn Cat! (1965)': 1018,
#  '20,000 Leagues Under the Sea (1954)': 1019,
#  'Cool Runnings (1993)': 1020,
#  'Angels in the Outfield (1994)': 1021,
#  'Cinderella (1950)': 1022,
#  'Winnie the Pooh and the Blustery Day (1968)': 1023,
#  'Three Caballeros, The (1945)': 1024,
#  ...}

# %%
tags.drop(['timestamp'], axis = 1, inplace = True)
ratings_t.drop(['timestamp'], axis = 1, inplace = True)

# %%
mixed = pd.merge(movies, tags, on='movieId', how = 'left')
mixed.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#   all_data  userId           tag
# 0            791.0         Owned
# 1           1048.0  imdb top 250
# 2           1361.0         Pixar
# 3           3164.0         Pixar
# 4           3164.0   time travel

# %%
mixed.fillna("", inplace = True)
mixed = pd.DataFrame(mixed.groupby('movieId')['tag'].apply(lambda x: "%s" % ' '.join(x)))
# Out:
# C:\Users\gauur\AppData\Local\Temp\ipykernel_1060\1285130730.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mixed.fillna("", inplace = True)

# %%
mixed
# Out:
#                                                        tag
# movieId
# 1        Owned imdb top 250 Pixar Pixar time travel chi...
# 2                       Robin Williams time travel fantasy
# 3                                                    funny
# 4
# 5
# ...                                                    ...
# 209049
# 209053
# 209055
# 209103
# 209163
#
# [31520 rows x 1 columns]

# %%
Final = pd.merge(movies, mixed, on='movieId', how = 'left')
Final
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 31515   209049               No Safe Spaces (2019)
# 31516   209053                      Bowling (2012)
# 31517   209055         Very Well, Thank You (2007)
# 31518   209103       Tsar Ivan the Terrible (1991)
# 31519   209163                    Bad Poems (2018)
#
#                                             genres all_data  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...      ...
# 31515                                  Documentary
# 31516                                       Comedy
# 31517                                 Comedy|Drama
# 31518                           (no genres listed)
# 31519                                 Comedy|Drama
#
#                                                      tag
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1                     Robin Williams time travel fantasy
# 2                                                  funny
# 3
# 4
# ...                                                  ...
# 31515
# 31516
# 31517
# 31518
# 31519
#
# [31520 rows x 5 columns]

# %%
Final.drop(['all_data'], axis = 1, inplace = True)
Final
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 31515   209049               No Safe Spaces (2019)
# 31516   209053                      Bowling (2012)
# 31517   209055         Very Well, Thank You (2007)
# 31518   209103       Tsar Ivan the Terrible (1991)
# 31519   209163                    Bad Poems (2018)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 31515                                  Documentary
# 31516                                       Comedy
# 31517                                 Comedy|Drama
# 31518                           (no genres listed)
# 31519                                 Comedy|Drama
#
#                                                      tag
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1                     Robin Williams time travel fantasy
# 2                                                  funny
# 3
# 4
# ...                                                  ...
# 31515
# 31516
# 31517
# 31518
# 31519
#
# [31520 rows x 4 columns]

# %%
Final ['metadata'] = Final[['tag', 'genres']].apply(lambda x: ' '.join(x), axis = 1)
Final
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 31515   209049               No Safe Spaces (2019)
# 31516   209053                      Bowling (2012)
# 31517   209055         Very Well, Thank You (2007)
# 31518   209103       Tsar Ivan the Terrible (1991)
# 31519   209163                    Bad Poems (2018)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 31515                                  Documentary
# 31516                                       Comedy
# 31517                                 Comedy|Drama
# 31518                           (no genres listed)
# 31519                                 Comedy|Drama
#
#                                                      tag  \
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1                     Robin Williams time travel fantasy
# 2                                                  funny
# 3
# 4
# ...                                                  ...
# 31515
# 31516
# 31517
# 31518
# 31519
#
#                                                 metadata
# 0      Owned imdb top 250 Pixar Pixar time travel chi...
# 1      Robin Williams time travel fantasy Adventure|C...
# 2                                   funny Comedy|Romance
# 3                                   Comedy|Drama|Romance
# 4                                                 Comedy
# ...                                                  ...
# 31515                                        Documentary
# 31516                                             Comedy
# 31517                                       Comedy|Drama
# 31518                                 (no genres listed)
# 31519                                       Comedy|Drama
#
# [31520 rows x 5 columns]

# %%
ratings_t
# Out:
#          userId  movieId  rating
# 70            2        1     3.5
# 71            2       62     0.5
# 72            2      110     5.0
# 73            2      150     4.0
# 74            2      151     4.5
# ...         ...      ...     ...
# 3077630   20261    79132     5.0
# 3077631   20261    80463     5.0
# 3077632   20261    80489     5.0
# 3077633   20261    81562     5.0
# 3077634   20261     <NA>     NaN
#
# [2615732 rows x 3 columns]

# %%
Final.shape
# Out:
# (31520, 5)

# %%
#colllaborative for the user ratings:

# %%
ratings_t.head()
# Out:
#     userId  movieId  rating
# 70       2        1     3.5
# 71       2       62     0.5
# 72       2      110     5.0
# 73       2      150     4.0
# 74       2      151     4.5

# %%
ratings_t.shape
# Out:
# (2615732, 3)

# %%
ratings_t1 = pd.merge(movies[['movieId']], ratings_t, on='movieId', how = 'right')

# %%
ratings_t1.shape
# Out:
# (2615732, 3)

# %%
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix

# %%
movies_users= ratings_t.pivot(index='movieId', columns='userId',values='rating').fillna(0)

# %%
movies_users.shape
# Out:
# (31590, 9147)

# %%
mat_movies_users=csr_matrix(movies_users.values)

# %%
model_knn= NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=20)

# %%
model_knn.fit(mat_movies_users)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=20)

# %%
from fuzzywuzzy import process #this is to get index of the movie

# %%
def recommender(movie_name, data,model, n_recommendations ):
    model.fit(data)
    idx=process.extractOne(movie_name, movies['title'])[2]
    print('Movie Selected: ',movies['title'][idx], 'Index: ',idx)
    print('Searching for recommendations.....')
    distances, indices=model.kneighbors(data[idx], n_neighbors=n_recommendations)
    for i in indices:
        print(movies['title'][i])

# %%
recommender('Jumanji (1995)', mat_movies_users, model_knn,20)
# Out:
# Movie Selected:  Jumanji (1995) Index:  1
# Searching for recommendations.....
# 1                                          Jumanji (1995)
# 352                    Four Weddings and a Funeral (1994)
# 476                                     Kalifornia (1993)
# 3000                          McCabe & Mrs. Miller (1971)
# 1237                            Back to the Future (1985)
# 258                                   Little Women (1994)
# 360                                  Little Buddha (1993)
# 1179    Star Wars: Episode VI - Return of the Jedi (1983)
# 1166    Star Wars: Episode V - The Empire Strikes Back...
# 581                     Terminator 2: Judgment Day (1991)
# 2465                                   Telling You (1998)
# 1522                               For Ever Mozart (1996)
# 1168    Raiders of the Lost Ark (Indiana Jones and the...
# 293                                        Panther (1995)
# 4158                                      Scarface (1983)
# 315                                  Shallow Grave (1994)
# 1232                                 Groundhog Day (1993)
# 586                Snow White and the Seven Dwarfs (1937)
# 582                             Dances with Wolves (1990)
# 4732                                        D.O.A. (1980)
# Name: title, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
